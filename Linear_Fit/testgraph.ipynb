# %%
import matplotlib.pyplot as plt
import numpy as np
import time
# %matplotlib notebook

# %%
# %store -r overlap_dict
# %store -r overlap_dict2

# %%
# %%time

plt.figure()
plt.plot(list(overlap_dict.keys()),list(overlap_dict.values()))
plt.yscale('log')
plt.title('Clean')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Wall time: 1min 59s

# %%
# %%time 

plt.figure()
plt.plot(list(overlap_dict2.keys()),list(overlap_dict2.values()))
plt.title('Divided Clean by Average (power law)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Wall time: 2min 27s

# %%
# from Least_Squares import LeastSquares
import Least_Squares
# c = LeastSquares()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-04969cd727e9> in <module>
#       1 # from Least_Squares import LeastSquares
# ----> 2 import Least_Squares
#       3 # c = LeastSquares()
#
# ModuleNotFoundError: No module named 'Least_Squares'
