# %%
import matplotlib.pyplot as plt
import numpy as np
import time
# %matplotlib notebook

# %%
# %store -r overlap_dict
# %store -r overlap_dict2
# %store -r noisy_dict

# %%
# %%time

plt.figure()
plt.plot(list(overlap_dict.keys()),list(overlap_dict.values()))
plt.yscale('log')
plt.title('Clean')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Wall time: 1min 14s

# %%
# %%time 

plt.figure()
plt.plot(list(overlap_dict2.keys()),list(overlap_dict2.values()))
plt.title('Divided Clean by Average (power law)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Wall time: 1min 44s

# %%
# %%time

plt.figure()
plt.plot(list(noisy_dict.keys()),list(noisy_dict.values()))
plt.yscale('log')
plt.title('Noisy')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Wall time: 2min 7s

# %%
# from Least_Squares import LeastSquares
# import Least_Squares
# c = LeastSquares()
